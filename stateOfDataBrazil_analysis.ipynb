# %% [markdown]
# <a href="https://colab.research.google.com/github/wandersonlira/state-of-data-brazil-2023/blob/main/stateOfDataBrazil_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este bloco de código converte o arquivo para UTF-8 em seguida cria outro arquivo com dados convertidos e salva no formato **.csv**

# %%
import pandas as pd


State_of_data_BR_2023 = pd.read_excel("/content/State_of_data_BR_2023.xlsx")

tabela = pd.DataFrame(State_of_data_BR_2023)

tabela.columns = tabela.columns.str.encode('latin1').str.decode('utf-8')

# Converte os dados para UTF-8
def converte_texto_para_utf8(celula):
    if isinstance(celula, str):
        try:
            return celula.encode('latin1').decode('utf-8')
        except (UnicodeEncodeError, UnicodeDecodeError):
            # Se ocorrer um erro, retorna o valor original
            return celula
    return celula


for column in tabela.columns:
    tabela[column] = tabela[column].apply(converte_texto_para_utf8)


# Salva uma cópia desses dados convertidos
tabela.to_csv("tabela_convertida.csv", encoding='utf-8', index=False)

# %% [markdown]
# Bloco de código que retira todo os caracteres especiais do arquivo que foi convertido para UTF-8.

# %%
import pandas as pd


tabela_convertida = pd.read_csv("/content/tabela_convertida.csv")

df = pd.DataFrame(tabela_convertida)


# Dicionário de substituições
substituicoes = {
    'ç': 'c', 'á': 'a', 'é': 'e', 'í': 'i', 'ó': 'o', 'ú': 'u',
    'ã': 'a', 'õ': 'o', 'â': 'a', 'ê': 'e', 'ô': 'o', 'à': 'a',
    'ü': 'u', 'Ç': 'C', 'Â': 'A', 'Ê': 'E', 'Ô': 'O',
    'Á': 'A', 'É': 'E', 'Í': 'I', 'Ó': 'O', 'Ú': 'U'
}


# Criar uma tabela de tradução
tabela_traducao = str.maketrans(substituicoes)

# Aplicar a tradução a todas as células do DataFrame
df = df.applymap(lambda celula: celula.translate(tabela_traducao) if isinstance(celula, str) else celula)


# Salva uma cópia desses dados convertidos
df.to_csv("stateOfDataBR2023_sem_caracteres_especiais.csv", encoding='utf-8', index=False)
# Out:
# <ipython-input-75-a463ed7f945f>:22: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda celula: celula.translate(tabela_traducao) if isinstance(celula, str) else celula)

# %%
import pandas as pd


tabela_convertida = pd.read_csv("/content/stateOfDataBR2023_sem_caracteres_especiais.csv")

df = pd.DataFrame(tabela_convertida)

display(df)
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     001b2d1qtli8t9z7oqgdhj001b2d4i0g                  31
# 1     0026aa3fwd78u0026asg7456tfkjg2cs                  30
# 2     00r21rb9pusd1b0v7ew00r21rw3dy69w                  37
# 3     00urm3jf2cek12w6ygue00urm3jzd17j                  22
# 4     00v0az4g792svil00vn6y1kfm9hq8vy9                  34
# ...                                ...                 ...
# 5288  zyg9519671iqrgy93qzyg95183k8ix5f                  34
# 5289  zyppgxzxko25qkgwsbrgpzyppgxzxs81                  32
# 5290  zysl5f50cnz3r0cbe6t2zysrxbzfsrng                  25
# 5291  zyt2656c9e1becxp457zyt26566dsng8                  31
# 5292  zzvyz3z5jy2lzzvyziv62lvtjrab9r5x                  31
#
#      ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                         30-34           Masculino
# 1                         30-34           Masculino
# 2                         35-39            Feminino
# 3                         22-24           Masculino
# 4                         30-34           Masculino
# ...                         ...                 ...
# 5288                      30-34           Masculino
# 5289                      30-34           Masculino
# 5290                      25-29           Masculino
# 5291                      30-34           Masculino
# 5292                      30-34           Masculino
#
#      ('P1_c ', 'Cor/raca/etnia') ('P1_d ', 'PCD')  \
# 0                         Branca              Nao
# 1                         Branca              Nao
# 2                        Amarela              Nao
# 3                          Preta              Nao
# 4                         Branca              Nao
# ...                          ...              ...
# 5288                       Preta              Nao
# 5289                      Branca              Nao
# 5290                      Branca              Nao
# 5291                       Parda              Nao
# 5292                     Amarela              Nao
#
#       ('P1_e ', 'experiencia_profissional_prejudicada')  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Sim, acredito que a minha a experiencia profis...
# 3     Nao acredito que minha experiencia profissiona...
# 4                                                   NaN
# ...                                                 ...
# 5288  Nao acredito que minha experiencia profissiona...
# 5289                                                NaN
# 5290                                                NaN
# 5291  Nao acredito que minha experiencia profissiona...
# 5292  Nao acredito que minha experiencia profissiona...
#
#       ('P1_e_1 ', 'Não acredito que minha experiência profissional seja afetada')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   1.0
# 4                                                   NaN
# ...                                                 ...
# 5288                                                1.0
# 5289                                                NaN
# 5290                                                NaN
# 5291                                                1.0
# 5292                                                1.0
#
#       ('P1_e_2 ', 'Experiencia prejudicada devido a minha Cor Raça Etnia')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   0.0
# 4                                                   NaN
# ...                                                 ...
# 5288                                                0.0
# 5289                                                NaN
# 5290                                                NaN
# 5291                                                0.0
# 5292                                                0.0
#
#       ('P1_e_3 ', 'Experiencia prejudicada devido a minha identidade de gênero')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   1.0
# 3                                                   0.0
# 4                                                   NaN
# ...                                                 ...
# 5288                                                0.0
# 5289                                                NaN
# 5290                                                NaN
# 5291                                                0.0
# 5292                                                0.0
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 5288  ...
# 5289  ...
# 5290  ...
# 5291  ...
# 5292  ...
#
#       ('P8_d_3 ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')  \
# 0                                                   1.0
# 1                                                   NaN
# 2                                                   1.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                0.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#      ('P8_d_4 ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')  \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                0.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#       ('P8_d_5 ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')  \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                1.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#       ('P8_d_6 ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')  \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                1.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#       ('P8_d_7 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')  \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                0.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#       ('P8_d_8 ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')  \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                0.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#       ('P8_d_9 ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')  \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                0.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#       ('P8_d_10 ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')  \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                0.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#       ('P8_d_11 ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')  \
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                0.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
#       ('P8_d_12 ', 'Treinando e aplicando LLM's para solucionar problemas de negócio.')
# 0                                                   0.0
# 1                                                   NaN
# 2                                                   0.0
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5288                                                NaN
# 5289                                                0.0
# 5290                                                NaN
# 5291                                                NaN
# 5292                                                NaN
#
# [5293 rows x 399 columns]
